# %%
# !nvidia-smi
# Out:
# Mon Mar 23 06:31:23 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="YOUR_API_KEY)

completion = client.chat.completions.create(
    model="deepseek/deepseek-r1",
    messages=[
        {"role": "user", "content": "Explain about software"}
    ]
)

print(completion.choices[0].message.content)
# Out:
# Software refers to the non-physical programs, applications, and operating systems that run on computer hardware, enabling it to perform specific tasks or operations. Essentially, it acts as a set of instructions—written in programming languages—that communicate with the hardware, directing it *what* to do and *how* to do it.
#
# ---
#
# ### Key Aspects of Software:
#
# 1. **Types and Categories:**
#    - **System Software:** Manages the hardware and basic system operations. Examples:
#      - Operating systems (e.g., Windows, macOS, Linux)
#      - Device drivers (enable hardware components to work with the OS)
#      - Utilities (tools for system maintenance, security, etc.)
#    - **Application Software:** Programs designed to help users perform tasks. Examples:
#      - Microsoft Office, web browsers (Chrome, Firefox), photo editors, games, etc.
#    - **Embedded Software:** Specialized software built into hardware devices, like in cars, appliances, or IoT devices.
#    - **Middleware:** Software that enables communication between different applications or systems.
#    - **Programming Software:** Tools for developers to write code (e.g., compilers, debuggers, IDEs like Visual Studio).
#
# 2. **How It Works:**
#    - Software is built using programming languages (Python, Java, C++, etc.) and compiled or interpreted into machine-readable code (binary).
#    - It interacts with hardware via the operating system, managing resources like memory, processing power, and storage.
#
# 3. **Software Development Process:**
#    - **Requirement Analysis:** Understand what the software needs to do.
#    - **Design:** Plan its architecture and user interface.
#    - **Implementation (Coding):** Write the code.
#    - **Testing:** Check for bugs and ensure quality.
#    - **Deployment:** Release to users.
#    - **Maintenance:** Update and fix issues over time.
#
# 4. **Modern Trends:**
#    - **Cloud-Based Software:** Software accessed over the internet (SaaS) rather than installed locally.
#    - **Open-Source Software:** Code that is publicly accessible and modifiable (e.g., Linux, VLC Media Player).
#    - **Artificial Intelligence and Machine Learning Integration:** Software that adapts, learns, and automates tasks.
#    - **Agile and DevOps:** Collaborative development and deployment approaches that prioritize speed and user feedback.
#
# 5. **Importance of Software:**
#    - Drives functionality of computers and smart devices.
#    - Enhances productivity, communication, and entertainment.
#    - Powers businesses, scientific research, healthcare systems, and education.
#    - Continuous innovation in software has enabled technologies like the Internet, smartphones, and smart homes.
#
# ---
#
# ### Example in Simple Terms:
# Think of hardware as the **body** of a computer (monitor, keyboard, hard drive), and software as its **mind**—the intelligence that lets it process tasks, run apps, and store data.
#
# ---
#
# ### Common Questions:
# - **Is software the same as an app?**
#   Not exactly—an "app" (application) is a type of software meant for end-users. Software can also include background programs like operating systems.
# - **Can software be updated?**
#   Yes—software is often updated to add features, fix security flaws, or improve performance.
# - **What’s the difference between software and firmware?**
#   Firmware is a specific type of software embedded in hardware, rarely updated.
#
# ---
#
# Software is the invisible force that empowers technology, making devices useful and adaptable. Without it, computers would be inert shells!
